# %%
import pandas as pd
import numpy as np
import seaborn as sns 
from sklearn import metrics
import matplotlib.pyplot as plt
house = pd.read_csv("house.csv")
house.head(3)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
#
# ...

# %%
house.isnull().sum()
house.dropna(axis=0,how='any',thresh=None,inplace=True)

# %%
plt.title('histogram of different ids')
plt.xlabel('id')
house['id'].plot.hist()
# Out:
# <AxesSubplot:title={'center':'histogram of different ids'}, xlabel='id', ylabel='Frequency'>

# %%
plt.title('histogram of prices')
plt.xlabel('price')
house['price'].plot.hist()
# Out:
# <AxesSubplot:title={'center':'histogram of prices'}, xlabel='price', ylabel='Frequency'>

# %%
plt.title('histogram of bedrooms')
plt.xlabel('bedrooms')
house['bedrooms'].plot.hist()
# Out:
# <AxesSubplot:title={'center':'histogram of bedrooms'}, xlabel='bedrooms', ylabel='Frequency'>

# %%
plt.title('histogram of bathrooms')
plt.xlabel('bathrooms')
house['bathrooms'].plot.hist()
# Out:
# <AxesSubplot:title={'center':'histogram of bathrooms'}, xlabel='bathrooms', ylabel='Frequency'>

# %%
plt.title('histogram of sqft_living')
plt.xlabel('sqft_living')
house['sqft_living'].plot.hist()
# Out:
# <AxesSubplot:title={'center':'histogram of sqft_living'}, xlabel='sqft_living', ylabel='Frequency'>

# %%
sns.distplot(house['sqft_lot'],bins=5,hist=True,kde=True,color='Red')
# Out:
# C:\Users\Nizar KHEMAKHEM\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sqft_lot', ylabel='Density'>

# %%
plt.title('histogram of floors')
plt.xlabel('floors')
house['floors'].plot.hist()
# Out:
# <AxesSubplot:title={'center':'histogram of floors'}, xlabel='floors', ylabel='Frequency'>

# %%
plt.title('histogram of waterfront')
plt.xlabel('waterfront')
house['waterfront'].plot.hist()
# Out:
# <AxesSubplot:title={'center':'histogram of waterfront'}, xlabel='waterfront', ylabel='Frequency'>

# %%
plt.title('histogram of view')
plt.xlabel('view')
house['view'].plot.hist()
# Out:
# <AxesSubplot:title={'center':'histogram of view'}, xlabel='view', ylabel='Frequency'>

# %%
plt.figure(figsize=(2,2))
sns.jointplot(x=house.lat.values, y=house.long.values, size=10)
plt.ylabel('Longitude', fontsize=12)
plt.xlabel('Latitude', fontsize=12)
plt.show()
# Out:
# C:\Users\Nizar KHEMAKHEM\anaconda3\lib\site-packages\seaborn\axisgrid.py:2073: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
plt.scatter(house.price,house.sqft_living)
plt.title("Price vs Square Feet")
# Out:
# Text(0.5, 1.0, 'Price vs Square Feet')

# %%
plt.scatter(house.price,house.long)
plt.title("Price vs yr_renovated ")
# Out:
# Text(0.5, 1.0, 'Price vs yr_renovated ')

# %%
plt.scatter(house.price,house.lat)
plt.xlabel("price")
plt.ylabel('Latitude')
plt.title("Latitude and Price")
# Out:
# Text(0.5, 1.0, 'Latitude and Price')

# %%
plt.scatter(house.price,house.lat)
plt.xlabel("price")
plt.ylabel('Longitude')
plt.title("Longitude and Price")
# Out:
# Text(0.5, 1.0, 'Longitude and Price')

# %%
plt.scatter((house['sqft_living']+house['sqft_basement']),house['price'])

# %%
from sklearn.model_selection import train_test_split
y=house['price'].values
xx= house[list(house.columns)[3:]]
x=house["sqft_basement"].values
X_train,X_test,Y_train,Y_test=train_test_split(xx,y,test_size=0.20,random_state=30)

# %%
X_train.shape,Y_train.shape
# Out:
# ((17290, 18), (17290,))

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression() 
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
predicted=model.predict(X_test)
print("R squared", metrics.r2_score(Y_test,predicted))
# Out:
# R squared 0.7182529653977057

# %%
house
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
X_train_changed
# Out:
# array([[ 970],
#        [2040],
#        [1830],
#        ...,
#        [3230],
#        [1930],
#        [1120]], dtype=int64)

# %%
print(Y_train.shape)
print(Y_train)
# Out:
# (17290,)
# [600000. 240000. 431000. ... 772500. 360000. 450000.]

# %%
Y_train_changed = Y_train.reshape(-1,1)
Y_train_changed.shape
# Out:
# (17290, 1)

# %%
Y_train_changed
# Out:
# array([[600000.],
#        [240000.],
#        [431000.],
#        ...,
#        [772500.],
#        [360000.],
#        [450000.]])

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression() 
model.fit(X_train_changed,Y_train_changed)
# Out:
# LinearRegression()

# %%
print(X_test.shape)
print(X_test)
# Out:
# (4323,)
# [2050 2380 2380 ... 3220 3240 2110]

# %%
X_test_nv = X_test.reshape(-1,1)
X_test_nv.shape
# Out:
# (4323, 1)

# %%
X_test_nv
# Out:
# array([[2050],
#        [2380],
#        [2380],
#        ...,
#        [3220],
#        [3240],
#        [2110]], dtype=int64)

# %%
plt.scatter(x,y,color="r")
plt.title("Linear Regression")
plt.ylabel("price")
plt.xlabel("sqft_living")
plt.plot(X_test,model.predict(X_test.reshape(-1,1)),color="k")
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
